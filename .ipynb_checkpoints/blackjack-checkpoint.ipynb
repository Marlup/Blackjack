# %% [markdown]
# ## Black Jack

# %%
import time
from blackjack import BlackJack, Color

# %% [markdown]
# Courtesy of https://stackoverflow.com/questions/8924173/how-can-i-print-bold-text-in-python

# %%
print(Color.BOLD + "Hello, World!" + Color.END)
# Out:
# Hello, World!

# %%
n_bots = 1
number_human_players = 1
automatic_game = False

blackjack_game = BlackJack(automatic_game=automatic_game, 
                           n_bots=n_bots,
                           n_human_players=number_human_players)
blackjack_game.loop_game()
# Out:
# ********************
# Round number: 1
# **********************
#
# +++++++++++++++++++++++
# Current probabilities
# +++++++++++++++++++++++
# Probability of getting card value less or equal to 12...
#
# Bot player 1 :
# ----------------
# Card value: 9
# Score: 9
# stand: False
# win: False
# ----------------
#
# +++++++++++++++++++++++
# Current probabilities
# +++++++++++++++++++++++
# Probability of getting card value less or equal to 14...
#
# Human player 2 :
# ----------------
# Card value: 7
# Score: 7
# stand: False
# win: False
# ----------------
#
# ********************
# Round number: 2
# **********************
#
# +++++++++++++++++++++++
# Current probabilities
# +++++++++++++++++++++++
# Probability of getting card value less or equal to 7...
#
# ...for deck 0 (49 elements): 46.94
#
# Probability for each card value:
#  [ 8.16  8.16  8.16  8.16  6.12  8.16  6.12  8.16  6.12 32.65]
# .........................................................
#
# ...
